# %%
import tensorflow as tf
import numpy as np

# %%
filenames = ["1.jpg", "2.jpg"]
class_names = ["Face Masked", "Face Masked"]

# %%
model = tf.keras.models.load_model("facemask model mobileNet 224")

# %%
index = 0
img_path = filenames[index]
img = tf.keras.preprocessing.image.load_img(
    img_path, target_size=(224, 224)
)
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely is {} with {:.2f}% confidence"
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# This image most likely is Face Masked with 67.70% confidence

# %%
from IPython.display import Image
Image(filenames[index])
